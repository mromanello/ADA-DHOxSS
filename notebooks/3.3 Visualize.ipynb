# %% [markdown]
# # 3.3 Visualizing data
#
# ## Motivation
#
# `pandas`' API provides integration with the plotting functionalities provided by the `matplotlib` library.
#
# This seamless integration – which is very nice! – hides away from users some of the complexities of `matplotlib`.
#
# However, as there cases where advanced customizations are needed, it's useful to learn the high-level plotting functionalities of `pandas` or `seaborn` as well as being aware of how to perform more advanced customizations by means of `matplotlib`.

# %% [markdown]
# ## Digging into `matplotlib`
#
# Very useful [`matplotlib` cheatsheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Anatomy of a plot

# %%
# %matplotlib inline

# first we create the figure, which is the 
# container where all plots reside
fig = plt.figure(figsize=(10, 10))

ax1 = fig.add_subplot(2, 2, 1)
plt.plot(np.random.randn(50), 'k--')

ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)
#plt.show()

# %% [markdown]
# Each plot resides within a `Figure` object.

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %% [markdown]
# Each subsplot resides within an `AxesSubplot` object.

# %%
type(ax1)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
# plt.subplots?

# %%
axes[0,0]
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
axes[0,0].plot(np.random.randn(50), 'y-')
axes[0,1].plot(np.random.randn(50), 'r--')
axes[0,1].plot(np.random.randn(50), 'b--')
axes[1,1].plot(np.random.randn(50), 'k--')
axes[1,0].plot(np.random.randn(50), '.')

fig.set_size_inches(8, 8)

# %% [markdown]
# ## Let's plot
#
# - number of contracts by corporation
# - distribution of length of contract, colored by corporation
# - plot of annual salary against length of contract, colored by genre
# - plot of annual salary against age at entry, colored by genre/gilda
# - annual salary by corporation

# %%
import os
import codecs
import pandas as pd

# %%
data_folder = "../data/apprenticeship_venice/"
df_contracts = pd.read_csv(
    codecs.open(os.path.join(data_folder,"professions_data.csv"),
                encoding="utf8"),
    sep=";"
)

# %%
df_contracts.head(2)
# Out:
#                                        page_title  \
# 0            Carlo Della sosta (Orese) 1592-08-03
# 1  Antonio quondam Andrea (squerariol) 1583-01-09
#
#                                             register  annual_salary  \
# 0  asv, giustizia vecchia, accordi dei garzoni, 1...            NaN
# 1  asv, giustizia vecchia, accordi dei garzoni, 1...           12.5
#
#   a_profession profession_code_strict profession_code_gen      profession_cat  \
# 0        orese                  orese             orefice             orefice
# 1   squerariol             squerariol  lavori allo squero  lavori allo squero
#
#    corporation  keep_profession_a  complete_profession_a  ...  \
# 0        Oresi                  1                      1  ...
# 1  Squerarioli                  1                      1  ...
#
#    personal_care_master  clothes_master  generic_expenses_master  \
# 0                     1               1                        1
# 1                     0               0                        1
#
#    salary_in_kind_master  pledge_goods_master  pledge_money_master  \
# 0                      0                    0                    0
# 1                      0                    0                    0
#
#   salary_master female_guarantor period_cat incremental_salary
# 0             0                0        NaN                  0
# 1             1                0        1.0                  0
#
# [2 rows x 47 columns]

# %%
df_contracts.corporation.unique()
# Out:
# array(['Oresi', 'Squerarioli', 'Battioro', 'Merzeri', 'Marangoni',
#        'Università dei Stampadori e Libreri', 'Specchieri', 'Tentori',
#        'Coroneri', 'Fabbri', 'Tiraoro', 'Da Colori', 'Cuoridoro',
#        'perleri', 'Tornidori', 'Pittori', 'Tagliapietra', 'Mureri',
#        'Libreri da carta bianca e da conti', 'Intagliatori',
#        'Merzeri . Stringheri . Teleroli', 'Merzeri . Stringheri', nan,
#        'Desegnadori', 'Carteri', 'Gioielleri', 'Latoneri',
#        'Musici e suonatori', 'Merzeri . Coroneri . Margariteri',
#        'Margariteri', 'Diamanteri', 'Tagliapietra . ', 'Sabioneri',
#        'Verieri', 'Cuoridoro . Merzeri', 'Indoratori', ' . ',
#        'Verieri da smalti', 'Varoteri', 'Merzeri . Teleroli',
#        'Teleroli . Merzeri . Bombasseri .  . Fustagneri',
#        'Merzeri . Teleroli .  . Fustagneri . Bombasseri', 'Specieri',
#        'Cereri', ' . Musici e suonatori', 'Oresi . Gioielleri',
#        'Strazzaroli . Merzeri', 'Merzeri . Carteri',
#        'Università dei Stampadori e Libreri . Miniadori',
#        'Capeleri . Merzeri', 'Università dei Stampadori e Libreri . ',
#        'Pittori . Indoratori', 'Merzeri . Merzeri',
#        'Merzeri . Bombasseri', 'Casseleri', 'Intagliatori . Marangoni',
#        'Miniadori', 'Teleroli . Merzeri . Stringheri',
#        'Merzeri . Margariteri', ' . Oresi', 'Cereri . Cereri',
#        'Teleroli . Merzeri', 'Stadierei . Latoneri', 'Merzeri . ',
#        'Tiraoro . Battioro', 'Terazzeri', 'Maschereri',
#        'Merzeri . Biavaroli', 'Tornidori . Intagliatori', 'Scultori',
#        'Battiargento', 'Margariteri . Margariteri',
#        'Arte della lana . Cereri', 'Marangoni . Mureri',
#        'Cereri . Specieri', 'Verieri da smalti . perleri',
#        'Merzeri . Stramazzeri', 'Battioro . Tiraoro',
#        'Barbieri / barbieri chirurghi', 'Capeleri', 'Petteneri',
#        'Botteri', 'Boccaleri e pignateri', 'Caldereri',
#        'Calegheri e zavatteri', 'pelterri', 'Cordeleri', 'Pirieri',
#        'Barcaioli', 'Muschieri',
#        'Università dei Stampadori e Libreri . Università dei Stampadori e Libreri',
#        'Spaderi', 'Miniadori . Desegnadori', 'Fenestreri', 'Sartori',
#        'Calcineri', 'Conzacurami',
#        'Stazioneri da vero . Boccaleri e pignateri . Cesteri',
#        'Casseleri . Marangoni', 'Stazioneri da vero',
#        'Capeleri . Sartori', 'Margariteri . ',
#        'Biavaroli . Malvasioti . Verieri',
#        'Casseleri . Intagliatori . Marangoni', 'Mandoleri . Da Colori',
#        'Occhialeri', 'Gua cortellini . Spaderi', 'Gua cortellini',
#        'Frutaroli . Verieri',
#        'Biavaroli . Verieri . Boccaleri e pignateri',
#        'Gioielleri . Oresi',
#        'Miniadori . Università dei Stampadori e Libreri',
#        'Sartori . Teleroli . Merzeri', 'Partioro',
#        'Teleroli . Stringheri . Merzeri', ' . Ligadori',
#        'Bombasseri . Merzeri',
#        'Merzeri . Università dei Stampadori e Libreri',
#        'Bombasseri . Stringheri', 'Merzeri . Teleroli . Stringheri',
#        'Oresi . ', 'Luganegheri . Frutaroli', 'Malvasioti', 'Stramazzeri',
#        'Burchieri', 'Centurieri', 'Pelteri', ' . Salumieri . ',
#        'Segadori', 'Arte della lana', 'Tesseri', 'Fustagneri',
#        'pescatori', 'Passamaner', 'Biavaroli . ', 'Luganegheri',
#        'Manganeri', 'Masteleri', 'Forneri',
#        'Barbieri / barbieri chirurghi . Barbieri / barbieri chirurghi',
#        'Strazzaroli', 'Casaroli', 'Conzacordami', 'Frutaroli', 'Linaroli',
#        'Filacanevi', 'Frutaroli . ', 'Bronzeri', 'Biavaroli', 'Erbaroli',
#        'Arte della seta', 'Curameri', 'Barcaroli', 'Mandoleri', 'Cesteri',
#        'Cordeleri . Passamaner', 'Barileri', 'Feraleri',
#        'Caldereri . Fabbri', 'Acquaroli', 'Bombasseri',
#        'Mandoleri . Frutaroli', ' . Salumieri', 'Pistori',
#        'Frutaroli . Mandoleri', 'Stramazzeri . Bombasseri', 'Remeri',
#        'Stringheri', 'Guanteri', 'Bareteri', 'Naranzeri', 'Acquavite',
#        'Luganegheri . Frutaroli .  . Salumieri', 'Burchieri . ',
#        'Biavaroli . Salumieri', 'pelterri . Latoneri', 'Teleroli',
#        'Cordeleri . Teleroli', 'Fornaseri', 'Sartori . Strazzaroli',
#        'Erbaroli . Frutaroli', 'Barcaioli . Burchieri',
#        'Frutaroli . Luganegheri . ', 'Casaroli . Salumieri . ',
#        'Mastelleri', 'Bolzeri', 'Frutaroli . Erbaroli . Fiorer',
#        'Specieri . Mandoleri', 'Sartori . Sartori', 'Scatoleri',
#        'Burchieri . Barcaioli', 'Stadierei', 'Cerchieri',
#        'Barbieri / barbieri chirurghi . Musici e suonatori',
#        'Casaroli .  . Saonero . Salumieri . ', 'Biavaroli . Frutaroli',
#        'Teleroli . Bombasseri .  . Fustagneri . Merzeri . Stramazzeri . Strazzaroli',
#        'Frutaroli . Coroneri', 'Calafati', 'Saoneri . Salumieri',
#        'Salumieri . Saoneri . ', ' . Merzeri . Specieri', 'Salumieri . ',
#        'Cordeleri . Bombasseri . Teleroli', 'Casaroli . Salumieri',
#        'Bombasseri . Stramazzeri', 'Mandoleri . Frutaroli . ',
#        'Teleroli . Stramazzeri', 'Verieri . Sabioneri',
#        'Bombasseri . Arte della lana', 'Salumieri', 'Casaroli . ',
#        'Filacanevi . Cordeleri', 'Saoneri . Acquavite',
#        ' . Salumieri . Biavaroli', 'Arte della seta . ',
#        'Stramazzeri . Bombasseri . Teleroli', 'Barileri . Masteleri',
#        'Acquavite . ', 'Travasadori da vin', ' .  . ',
#        'Stringheri . Calegheri e zavatteri', 'Passamaner . Cordeleri',
#        'Calegheri e zavatteri . Acquavite', 'Salumieri . Luganegheri . ',
#        'Frutaroli . Erbaroli', 'Saoneri . Salumieri . ',
#        'Biavaroli . Frutaroli . ', 'Intagliatori . Tornidori',
#        'Biavaroli . Salumieri . ', ' . Salumieri . Merzeri',
#        'Muschieri . Varoteri',
#        'Bombasseri . Teleroli . Merzeri . Fustagneri . Bolzeri',
#        'Desegnadori . ', 'Marangoni . Casseleri', 'Frutaroli . Naranzeri',
#        'Barbieri / barbieri chirurghi . Merzeri',
#        'Stramazzeri . Specieri', 'Specieri . Stramazzeri',
#        'Arte della lana . ', 'Mandoleri . ', 'Conzacurami . ', 'Latoner',
#        'Pistori . ', 'Linaroli . Naranzeri',
#        'Merzeri . Biavaroli . Salumieri', 'Mureri . Mureri',
#        'Merzeri . Strazzaroli . Stringheri',
#        'Bombasseri . Stringheri . Merzeri', 'Merzeri . Arte della lana',
#        ' . Biavaroli', 'Bottoneri . ', 'Mureri . Marangoni',
#        'Specieri . Merzeri', 'Stringheri . Merzeri',
#        'Stadierei . Merzeri', 'Tagliapietra . Intagliatori',
#        'Indoratori . Miniadori', 'Marangoni . Segadori',
#        'Scaleteri . perleri', 'Merzeri . Passamaner',
#        'Da Colori . Mandoleri', 'Casseleri . Specchieri',
#        'Merzeri . Tornidori', 'Mureri . Tagliapietra',
#        'Marangoni . Intagliatori', 'Merzeri . Bombasseri . Stringheri',
#        ' . Merzeri', 'Merzeri . Fenestreri', 'Miniadori . Specchieri',
#        'Frutaroli . Biavaroli . Verieri', 'Linaroli . Biavaroli',
#        ' .  . Salumieri', 'Linaroli . ',
#        'Bombasseri . Stramazzeri . Teleroli .  . Fustagneri',
#        'Frutaroli . Merzeri', ' . Luganegheri',
#        'Casaroli .  . Biavaroli . Salumieri', 'Specieri . ',
#        'Strazzaroli . Sartori', 'Merzeri . Arte della seta',
#        'Scultori . Pittori', 'Bossoleri', 'Petteneri . Merzeri',
#        'Bossoleri . Carteri', 'Biavaroli . Verieri', 'Ligadori',
#        'Sartori . Desegnadori', 'Corieri Veneti',
#        'Frutaroli . Mandoleri . ', 'Passamaner . ', 'Merzeri . Sartori',
#        'Merzeri . Stringheri . Linaroli', 'Frutaroli . pescatori',
#        ' . Biavaroli . Salumieri', ' . Bottoneri',
#        'Luganegheri .  . Salumieri', 'Acquavite . Gua cortellini',
#        'Fustagneri . Tesseri', 'pettenadori', ' . Linaroli',
#        'Bombasseri . Stramazzeri . Teleroli . ',
#        'Barbieri / barbieri chirurghi . Barbieri / barbieri chirurghi . Musici e suonatori',
#        'Bottoneri'], dtype=object)

# %%
df_contracts.shape
# Out:
# (9653, 47)

# %%
filter_corporation = [
    "Oresi",
    "Specieri",
    "Marangoni",
    "Università dei Stampadori e Libreri"
]

# %%
contracts_zoom_df = df_contracts[df_contracts.corporation.isin(filter_corporation)]

# %%
contracts_zoom_df.shape
# Out:
# (1945, 47)

# %% [markdown]
# ### Plot: number of contracts by corporation

# %%
contracts_zoom_df[['page_title']]
# Out:
#                                              page_title
# 0                  Carlo Della sosta (Orese) 1592-08-03
# 5                 Andrea Manfredo (marangon) 1664-02-04
# 6     Marcho de Zuane (all'arte della stampa) 1621-1...
# 11                 Andrea Zangiardo (librer) 1645-07-28
# 22              Carletto Barbarigo (orefice) 1621-08-31
# ...                                                 ...
# 9611          Zamaria de Gasparo (stampador) 1645-11-28
# 9612        Girardo de Zuan Piero (marangon) 1593-04-07
# 9631  Gierolimo Marchi (speciale da confesion) 1622-...
# 9637                  Piero Torella (librer) 1645-01-02
# 9639               Alvise Padella (marangon) 1594-05-17
#
# [1945 rows x 1 columns]

# %%
pd.pivot_table(
    contracts_zoom_df,
    index='corporation',
    aggfunc={'female_guarantor': 'sum'}
)
# Out:
#                                      female_guarantor
# corporation
# Marangoni                                          20
# Oresi                                              42
# Specieri                                            4
# Università dei Stampadori e Libreri                13

# %%
corporation_size = pd.pivot_table(
    contracts_zoom_df,
    index='corporation',
    aggfunc={'page_title': 'count'}
)

# %%
corporation_size
# Out:
#                                      page_title
# corporation
# Marangoni                                   748
# Oresi                                       640
# Specieri                                    158
# Università dei Stampadori e Libreri         399

# %%
# let's reshape the data
# to make plotting easier

corporation_size = pd.pivot_table(
    contracts_zoom_df,
    index='corporation',
    aggfunc={'page_title': 'count'}
).rename(columns={'page_title':'size'})

# %%
corporation_size
# Out:
#                                      size
# corporation
# Marangoni                             748
# Oresi                                 640
# Specieri                              158
# Università dei Stampadori e Libreri   399

# %%
# first try

ax = corporation_size.plot.bar()

# %% [markdown]
# #### Legend

# %%
# second try
# remove the legend as it does not make much sense in this case

ax = corporation_size.plot.bar(legend=False)

# %% [markdown]
# #### Label the axes

# %%
# third try
# we rotate the tick labels on the x axis

ax = corporation_size.plot.bar(
    legend=False,
    rot=10, # rotate tick labels on x axis
    figsize=(6, 4),
    fontsize="large" # try changing to 9, 14, 26
)

# set a readable title for the plot
ax.set_title('Number of contracts by corporation')

# label the y axis
ax.set_ylabel('Contracts')

# remove the x axis as it clutters the plot
xlabel = ax.set_xlabel('')

# %% [markdown]
# #### Save

# %% [markdown]
# To save our plot, we need to get the `Figure` element that contains it:

# %%
fig = ax.get_figure()
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
fig.savefig('figures/plot1.png')

# %%
# if you are publishing an article, they will
# ask you images with min 300 dpi

fig.savefig('figures/plot1_300dpi.png', dpi=300)

# %% [markdown]
# **Exercise**: rename the "Università dei Stampadori e Libreri" to "Stampadori e Libreri" before plotting the data.
#
# (**Hint**: the renaming is easier if before pivoting the data you cast `corporation` to categorical data)

# %% [markdown]
# ### Plot: annual salary vs length of contract

# %%
contracts_zoom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1945 entries, 0 to 9639
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   page_title                1945 non-null   object
#  1   register                  1945 non-null   object
#  2   annual_salary             1633 non-null   float64
#  3   a_profession              1945 non-null   object
#  4   profession_code_strict    1945 non-null   object
#  5   profession_code_gen       1945 non-null   object
#  6   profession_cat            1945 non-null   object
#  7   corporation               1945 non-null   object
#  8   keep_profession_a         1945 non-null   int64
#  9   complete_profession_a     1945 non-null   int64
#  10  enrolmentY                1941 non-null   float64
#  11  enrolmentM                1942 non-null   float64
#  12  startY                    1924 non-null   float64
#  13  startM                    1927 non-null   float64
#  14  length                    1944 non-null   float64
#  15  has_fled                  1945 non-null   int64
#  16  m_profession              1932 non-null   object
#  17  m_profession_code_strict  1932 non-null   object
#  18  m_profession_code_gen     1932 non-null   object
#  19  m_profession_cat          1932 non-null   object
#  20  m_corporation             1931 non-null   object
#  21  keep_profession_m         1945 non-null   int64
#  22  complete_profession_m     1945 non-null   int64
#  23  m_gender                  1912 non-null   float64
#  24  m_name                    1938 non-null   object
#  25  m_surname                 1490 non-null   object
#  26  m_patronimic              456 non-null    object
#  27  m_atelier                 146 non-null    object
#  28  m_coords                  1944 non-null   object
#  29  a_name                    1945 non-null   object
#  30  a_age                     1891 non-null   float64
#  31  a_gender                  1908 non-null   float64
#  32  a_geo_origins             1385 non-null   object
#  33  a_geo_origins_std         984 non-null    object
#  34  a_coords                  1938 non-null   object
#  35  a_quondam                 1620 non-null   float64
#  36  accommodation_master      1945 non-null   int64
#  37  personal_care_master      1945 non-null   int64
#  38  clothes_master            1945 non-null   int64
#  39  generic_expenses_master   1945 non-null   int64
#  40  salary_in_kind_master     1945 non-null   int64
#  41  pledge_goods_master       1945 non-null   int64
#  42  pledge_money_master       1945 non-null   int64
#  43  salary_master             1945 non-null   int64
#  44  female_guarantor          1945 non-null   int64
#  45  period_cat                1629 non-null   float64
#  46  incremental_salary        1945 non-null   int64
# dtypes: float64(11), int64(15), object(21)
# memory usage: 729.4+ KB

# %%
contracts_zoom_df.plot.scatter(x='annual_salary', y='length')
# Out:
# <AxesSubplot:xlabel='annual_salary', ylabel='length'>

# %% [markdown]
# #### Meet `seaborn`
#
# `seaborn` is a library built on top of `matplotlib` which complements and extends its functionalities.
#
# - themes
# - color palettes
# - customizing `seaborn` plots

# %%
import seaborn as sns

# %%
ax = sns.scatterplot(
    x='annual_salary',
    y='length',
    data=contracts_zoom_df,
    hue='corporation'
)

ax.set_xlabel('Annual salary (ducati)')
ax.set_ylabel('Contract length (years)')

fig = ax.get_figure()
fig.set_size_inches(10,8)

# %%
ax = sns.scatterplot(
    x='annual_salary',
    y='length',
    data=contracts_zoom_df,
    hue='corporation'
)

ax.set_xlabel('Annual salary (ducati)')
ax.set_ylabel('Contract length (years)')

fig = ax.get_figure()
fig.set_size_inches(10,8)

# %%
contracts_zoom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1945 entries, 0 to 9639
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   page_title                1945 non-null   object
#  1   register                  1945 non-null   object
#  2   annual_salary             1633 non-null   float64
#  3   a_profession              1945 non-null   object
#  4   profession_code_strict    1945 non-null   object
#  5   profession_code_gen       1945 non-null   object
#  6   profession_cat            1945 non-null   object
#  7   corporation               1945 non-null   object
#  8   keep_profession_a         1945 non-null   int64
#  9   complete_profession_a     1945 non-null   int64
#  10  enrolmentY                1941 non-null   float64
#  11  enrolmentM                1942 non-null   float64
#  12  startY                    1924 non-null   float64
#  13  startM                    1927 non-null   float64
#  14  length                    1944 non-null   float64
#  15  has_fled                  1945 non-null   int64
#  16  m_profession              1932 non-null   object
#  17  m_profession_code_strict  1932 non-null   object
#  18  m_profession_code_gen     1932 non-null   object
#  19  m_profession_cat          1932 non-null   object
#  20  m_corporation             1931 non-null   object
#  21  keep_profession_m         1945 non-null   int64
#  22  complete_profession_m     1945 non-null   int64
#  23  m_gender                  1912 non-null   float64
#  24  m_name                    1938 non-null   object
#  25  m_surname                 1490 non-null   object
#  26  m_patronimic              456 non-null    object
#  27  m_atelier                 146 non-null    object
#  28  m_coords                  1944 non-null   object
#  29  a_name                    1945 non-null   object
#  30  a_age                     1891 non-null   float64
#  31  a_gender                  1908 non-null   float64
#  32  a_geo_origins             1385 non-null   object
#  33  a_geo_origins_std         984 non-null    object
#  34  a_coords                  1938 non-null   object
#  35  a_quondam                 1620 non-null   float64
#  36  accommodation_master      1945 non-null   int64
#  37  personal_care_master      1945 non-null   int64
#  38  clothes_master            1945 non-null   int64
#  39  generic_expenses_master   1945 non-null   int64
#  40  salary_in_kind_master     1945 non-null   int64
#  41  pledge_goods_master       1945 non-null   int64
#  42  pledge_money_master       1945 non-null   int64
#  43  salary_master             1945 non-null   int64
#  44  female_guarantor          1945 non-null   int64
#  45  period_cat                1629 non-null   float64
#  46  incremental_salary        1945 non-null   int64
# dtypes: float64(11), int64(15), object(21)
# memory usage: 729.4+ KB

# %% [markdown]
# ### Plot: annual salary by corporation

# %%
axes = contracts_zoom_df.hist(
    column='annual_salary',
    by='corporation',
    sharex=False,
    sharey=True,
    figsize=(8,8),
)

# %% [markdown]
# Combining hue and size of data points to add information to the scatter plot:

# %%
ax = sns.scatterplot(
    x='a_age',
    y='length',
    size='annual_salary',
    data=contracts_zoom_df,
    hue='a_gender'
)

ax.set_xlabel('Apprentiship\'s age')
ax.set_ylabel('Contract length (years)')

fig = ax.get_figure()
fig.set_size_inches(10,8)

# %%
fig.savefig('figures/plot2.png', dpi=300)

# %%
ax = sns.lmplot(
    x="a_age",
    y="length",
    data=contracts_zoom_df,
    fit_reg=False,
    col='corporation',
    col_wrap=2
)
ax.set_xlabels('Apprentice age')
ax.set_ylabels('Contract length')

# %%
ax = sns.lmplot(
    x="a_age",
    y="length",
    data=contracts_zoom_df,
    fit_reg=False,
    col='corporation',
    hue='a_gender',
    col_wrap=2
)
ax.set_xlabels('Apprentice age')
ax.set_ylabels('Contract length')

# %% [markdown]
# ## Controlling aestethics with seaborn
#
# See this tutorial http://seaborn.pydata.org/tutorial/aesthetics.html

# %% [markdown]
# ---
